# %% [markdown]
# #### 1.1

# %%
###Paso 1: importar paqueteria matplotlib
import matplotlib.pyplot as plt

# %%
### Paso 2. Datos del problema
Datos=[3.4,2.5,4.8,2.9,3.6,2.8,3.3,5.6,3.7,2.8,4.4,4.0,5.2,3.0,4.8]

# %%
#c)
plt.plot(Datos, "o",color="k")

# %%
#d
n=len(Datos)
print(f'La muestra es de tamaño n= {n}')
#media recortadaa al 20%
mr=0.20*(n)
print(f'quitaremos {mr} datos en cada extremo')
# Out:
# La muestra es de tamaño n= 15
# quitaremos 3.0 datos en cada extremo
